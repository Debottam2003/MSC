# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from dataset import raw_dataset as data

df = pd.DataFrame(data)
print(df)

linkage_methods = ['single', 'complete', 'average']

for i in linkage_methods:
    plt.figure(figsize=(8,5))
    link = linkage(df, method=i)
    dendrogram(link, orientation="bottom")
    plt.title(f"Dendrogram for AGNES ({i} linkage)")
    plt.show()
# Out:
#     individual    x    y
# 0            1  1.0  1.0
# 1            2  1.5  2.0
# 2            3  2.0  1.5
# 3            4  1.8  2.2
# 4            5  2.5  2.0
# 5            6  2.2  1.8
# 6            7  3.0  4.0
# 7            8  3.5  4.5
# 8            9  3.2  3.8
# 9           10  4.0  4.2
# 10          11  3.8  4.8
# 11          12  4.5  5.0
# 12          13  5.0  5.5
# 13          14  5.2  6.0
# 14          15  4.8  5.8
# 15          16  5.5  6.5
# 16          17  6.0  7.0
# 17          18  5.8  6.8
# 18          19  6.2  7.2
# 19          20  6.5  7.5

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Input sample and target
X = np.array([[1, 1, 0, 1]])
T = np.array([[1, 0]])

# Build network: 4–3–2–2
model = Sequential([
    Dense(3, activation='sigmoid', input_shape=(4,), name="Hidden_Layer_1"),
    Dense(2, activation='sigmoid', name="Hidden_Layer_2"),
    Dense(2, activation='sigmoid', name="Output_Layer")
])

# Compile model
model.compile(optimizer='sgd', loss='mse')

# Train for 25 epoch
model.fit(X, T, epochs=25, verbose=1)

# Predict output
output = model.predict(X)
print("\nNetwork Output:", output)

# -------------------------------
# Print Weights and Biases
# -------------------------------
print("\n--- Weights and Biases After Training ---")

for layer in model.layers:
    weights, biases = layer.get_weights()

    print(f"\nLayer Name: {layer.name}")
    print("Weights Matrix:")
    print(weights)

    print("Bias Vector:")
    print(biases)
# Out:
# Epoch 1/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.1558
# Epoch 2/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1554
# Epoch 3/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1551
# Epoch 4/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1547
# Epoch 5/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1544
# Epoch 6/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1540
# Epoch 7/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1536
# Epoch 8/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1533
# Epoch 9/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1529
# Epoch 10/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1526
# Epoch 11/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1523
# Epoch 12/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1519
# Epoch 13/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1516
# Epoch 14/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1512
# Epoch 15/25
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz

# Generate sample data
X = np.array([
    [1, 2],
    [2, 3],
    [3, 3],
    [8, 7],
    [9, 8],
    [10, 9]
])

# Transpose data (required format)
data = X.T

print(data)

# Apply Fuzzy C-Means
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    data,
    c=2,              # Number of clusters
    m=2,              # Fuzziness coefficient
    error=0.005,
    maxiter=1000,
    init=None
)

# Cluster membership
cluster_labels = np.argmax(u, axis=0)
print(cluster_labels)

print("Cluster Centers:\n", cntr)
print("Membership Matrix:\n", u)

# Plot result
plt.scatter(X[:, 0], X[:, 1], c=cluster_labels)
plt.scatter(cntr[:, 0], cntr[:, 1], marker='X', s=200, c='red')
plt.title("Fuzzy C-Means Clustering")
plt.show()
# Out:
# [[ 1  2  3  8  9 10]
#  [ 2  3  3  7  8  9]]
# [0 0 0 1 1 1]
# Cluster Centers:
#  [[2.00179804 2.67170722]
#  [9.00888494 8.00914117]]
# Membership Matrix:
#  [[9.85696238e-01 9.98549866e-01 9.82277027e-01 3.58812198e-02
#   2.10045509e-06 1.85323783e-02]
#  [1.43037615e-02 1.45013396e-03 1.77229725e-02 9.64118780e-01
#   9.99997900e-01 9.81467622e-01]]
